# %%
#initializing the libraries required to read the data. I will be maintaining the same set of libariries throughout the project
import seaborn as sns
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import zipfile
from pathlib import Path
import datetime
# Default plot configurations
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16,8)
plt.rcParams['figure.dpi'] = 150
sns.set()


from IPython.display import display, Latex, Markdown

# %%
#the columns names manually writen here from the taxonomy file since the csv files don't begin with a header
column_names = ["Username", "Name", "Birth Year", "Gender", "Skillset1", "Skillset1 Weight", "Skillset2", "Skillset2 Weight", "City","Country", "Education(highest degree attained)", "Elite Instituition", "Start Date", "???", "End Date", "???", "???", "Length", "Role", "Department", "Company Name", "Normalized Company Name", "Ticker", "Exchange", "Flag", "Location", "Industry", "Education Flag", "Degree Type", "Elite Flag", "Major", "Department(major category)", "FIGI", "Time Stamp"]

# %% [markdown]
# # Reading the Tab-delimited files into pandas's dataframe and the column names are specified.

# %%
LEH = pd.read_csv("LEH_profiles.csv", sep = '\t', header = None, names = column_names )
LEH.head(5)
# Out:
#                                Username        Name Birth Year  Gender  \
# 0  ee4460d1-2bfd-3869-be44-353e1d8edf70  Maida Baez       1983       1
# 1  ee4460d1-2bfd-3869-be44-353e1d8edf70  Maida Baez       1983       1
# 2  ee4460d1-2bfd-3869-be44-353e1d8edf70  Maida Baez       1983       1
# 3  ee4460d1-2bfd-3869-be44-353e1d8edf70  Maida Baez       1983       1
# 4  ee4460d1-2bfd-3869-be44-353e1d8edf70  Maida Baez       1983       1
#
#   Skillset1  Skillset1 Weight Skillset2  Skillset2 Weight      City  \
# 0        -1               0.0        -1               0.0  New York
# 1        -1               0.0        -1               0.0  New York
# 2        -1               0.0        -1               0.0  New York
# 3        -1               0.0        -1               0.0  New York
# 4        -1               0.0        -1               0.0  New York
#
#          Country      ...         Flag       Location  Industry  \
# 0  United States      ...        False            NaN       NaN
# 1  United States      ...        False  United States  TIME_OFF
# 2  United States      ...        False            NaN       NaN
# 3  United States      ...        False            NaN       NaN
# 4  United States      ...         True            NaN    522110
#
#   Education Flag Degree Type  Elite Flag  Major  Department(major category)  \
# 0          False         NaN       False    NaN                         NaN
# 1          False         NaN       False    NaN                         NaN
# 2           True         4.0       False    NaN                         NaN
# 3          False         NaN       False    NaN                         NaN
# 4          False         NaN       False    NaN                         NaN
#
#   FIGI     Time Stamp
# 0  NaN  1540027831000
# 1  NaN  1540027831000
# 2  NaN  1540027831000
# 3  NaN  1540027831000
# 4  NaN  1540027831000
#
# [5 rows x 34 columns]

# %%
DB = pd.read_csv("DB_profiles.csv", sep = '\t', header = None, names = column_names )
DB.head()
# Out:
#                                Username             Name Birth Year  Gender  \
# 0  32c1439f-81b4-37cd-85b1-88c0f004b586      Adam Gelder       1974       2
# 1  32c1439f-81b4-37cd-85b1-88c0f004b586      Adam Gelder       1974       2
# 2  32c1439f-81b4-37cd-85b1-88c0f004b586      Adam Gelder       1974       2
# 3  32c1439f-81b4-37cd-85b1-88c0f004b586      Adam Gelder       1974       2
# 4  52239a8f-09fb-375b-8e3f-39504d5b2619  Charlotte Jones       1963       1
#
#              Skillset1  Skillset1 Weight                Skillset2  \
# 0                   -1          0.000000                       -1
# 1                   -1          0.000000                       -1
# 2                   -1          0.000000                       -1
# 3                   -1          0.000000                       -1
# 4  Banking and Finance          0.994788  Accounting and Auditing
#
#    Skillset2 Weight    City         Country      ...         Flag  \
# 0          0.000000  London  United Kingdom      ...        False
# 1          0.000000  London  United Kingdom      ...        False
# 2          0.000000  London  United Kingdom      ...         True
# 3          0.000000  London  United Kingdom      ...         True
# 4          0.002872  London  United Kingdom      ...        False
#
#                  Location  Industry Education Flag Degree Type Elite Flag  \
# 0                     NaN       NaN           True         4.0      False
# 1          United Kingdom  TIME_OFF          False         NaN      False
# 2                     NaN    522110          False         NaN      False
# 3  london, united kingdom    522110          False         NaN      False
# 4                     NaN       NaN           True         NaN      False
#
#    Major  Department(major category)          FIGI     Time Stamp
# 0    NaN                         NaN           NaN  1538931557000
# 1    NaN                         NaN           NaN  1538931557000
# 2    NaN                         NaN  BBG000BBZTH2  1538931557000
# 3    NaN                         NaN  BBG000BD8PN9  1538931557000
# 4    NaN                         NaN           NaN  1540024512000
#
# [5 rows x 34 columns]

# %%
GS = pd.read_csv("GS_profiles.csv", sep = '\t', header = None, names = column_names )
GS.head()
# Out:
#                                Username             Name Birth Year  Gender  \
# 0  547a14dc-af64-3970-8f82-6a7c79e7bc54  John Harrisingh       1960       2
# 1  547a14dc-af64-3970-8f82-6a7c79e7bc54  John Harrisingh       1960       2
# 2  547a14dc-af64-3970-8f82-6a7c79e7bc54  John Harrisingh       1960       2
# 3  547a14dc-af64-3970-8f82-6a7c79e7bc54  John Harrisingh       1960       2
# 4  547a14dc-af64-3970-8f82-6a7c79e7bc54  John Harrisingh       1960       2
#
#   Skillset1  Skillset1 Weight Skillset2  Skillset2 Weight           City  \
# 0        -1               0.0        -1               0.0  New Brunswick
# 1        -1               0.0        -1               0.0  New Brunswick
# 2        -1               0.0        -1               0.0  New Brunswick
# 3        -1               0.0        -1               0.0  New Brunswick
# 4        -1               0.0        -1               0.0  New Brunswick
#
#          Country      ...         Flag                    Location  Industry  \
# 0  United States      ...        False                         NaN       NaN
# 1  United States      ...        False                         NaN       NaN
# 2  United States      ...        False               United States  TIME_OFF
# 3  United States      ...        False  greater new york city area        54
# 4  United States      ...         True          new york, new york    523110
#
#   Education Flag Degree Type Elite Flag              Major  \
# 0           True         4.0      False  political science
# 1           True         7.0      False                law
# 2          False         NaN      False                NaN
# 3          False         NaN      False                NaN
# 4          False         NaN      False                NaN
#
#    Department(major category)          FIGI     Time Stamp
# 0             Social Sciences           NaN  1539000420000
# 1             Social Sciences           NaN  1539000420000
# 2                         NaN           NaN  1539000420000
# 3                         NaN           NaN  1539000420000
# 4                         NaN  BBG000BS1R22  1539000420000
#
# [5 rows x 34 columns]

# %%
MS = pd.read_csv("MS_profiles.csv", sep = '\t', header = None, names = column_names )
MS.head()
# Out:
#                                Username           Name Birth Year  Gender  \
# 0  80eb339c-c4c9-35f6-bc59-b6ad21b922fd  Nadine Dániel       1981       1
# 1  80eb339c-c4c9-35f6-bc59-b6ad21b922fd  Nadine Dániel       1981       1
# 2  80eb339c-c4c9-35f6-bc59-b6ad21b922fd  Nadine Dániel       1981       1
# 3  80eb339c-c4c9-35f6-bc59-b6ad21b922fd  Nadine Dániel       1981       1
# 4  80eb339c-c4c9-35f6-bc59-b6ad21b922fd  Nadine Dániel       1981       1
#
#   Skillset1  Skillset1 Weight Skillset2  Skillset2 Weight City  Country  \
# 0        -1               0.0        -1               0.0  NaN  Hungary
# 1        -1               0.0        -1               0.0  NaN  Hungary
# 2        -1               0.0        -1               0.0  NaN  Hungary
# 3        -1               0.0        -1               0.0  NaN  Hungary
# 4        -1               0.0        -1               0.0  NaN  Hungary
#
#        ...         Flag                         Location Industry  \
# 0      ...        False                              NaN      NaN
# 1      ...        False                              NaN      NaN
# 2      ...        False                              NaN       11
# 3      ...        False  frankfurt am main area, germany       42
# 4      ...        False                              NaN      NaN
#
#   Education Flag Degree Type Elite Flag       Major  \
# 0           True         4.0      False         NaN
# 1           True         NaN      False  management
# 2          False         NaN      False         NaN
# 3          False         NaN      False         NaN
# 4           True         NaN      False      german
#
#    Department(major category) FIGI     Time Stamp
# 0                         NaN  NaN  1524913898000
# 1             Social Sciences  NaN  1524913898000
# 2                         NaN  NaN  1524913898000
# 3                         NaN  NaN  1524913898000
# 4                  Humanities  NaN  1524913898000
#
# [5 rows x 34 columns]

# %%
UBS = pd.read_csv("UBS_profiles.csv", sep = '\t', header = None, names = column_names )
UBS.head()
# Out:
#                                Username              Name Birth Year  Gender  \
# 0  b2f27b89-832f-3b03-aaf2-87d6e2ac714f  Lorenz Pfisterer       1981       2
# 1  b2f27b89-832f-3b03-aaf2-87d6e2ac714f  Lorenz Pfisterer       1981       2
# 2  b2f27b89-832f-3b03-aaf2-87d6e2ac714f  Lorenz Pfisterer       1981       2
# 3  b2f27b89-832f-3b03-aaf2-87d6e2ac714f  Lorenz Pfisterer       1981       2
# 4  b2f27b89-832f-3b03-aaf2-87d6e2ac714f  Lorenz Pfisterer       1981       2
#
#   Skillset1  Skillset1 Weight Skillset2  Skillset2 Weight  City      Country  \
# 0        -1               0.0        -1               0.0  Bern  Switzerland
# 1        -1               0.0        -1               0.0  Bern  Switzerland
# 2        -1               0.0        -1               0.0  Bern  Switzerland
# 3        -1               0.0        -1               0.0  Bern  Switzerland
# 4        -1               0.0        -1               0.0  Bern  Switzerland
#
#        ...         Flag  Location Industry Education Flag Degree Type  \
# 0      ...        False       NaN      NaN           True         5.0
# 1      ...         True       NaN   523920          False         NaN
# 2      ...        False       NaN      NaN          False         NaN
# 3      ...         True       NaN   523920          False         NaN
# 4      ...        False       NaN      NaN          False         NaN
#
#   Elite Flag  Major  Department(major category)          FIGI     Time Stamp
# 0      False    NaN                         NaN           NaN  1538827523000
# 1      False    NaN                         NaN  BBG007DJM539  1538827523000
# 2      False    NaN                         NaN           NaN  1538827523000
# 3      False    NaN                         NaN  BBG007DJM539  1538827523000
# 4      False    NaN                         NaN           NaN  1538827523000
#
# [5 rows x 34 columns]

# %%
# Identifying the number of rows in each dataset 
LEH.shape,DB.shape, UBS.shape, MS.shape,GS.shape
# Out:
# ((102103, 34), (161792, 34), (217621, 34), (141492, 34), (104006, 34))

# %% [markdown]
# # Identifying the number of employees in each dataset

# %%
LEH["Username"].nunique()
# Out:
# 12790

# %%
DB["Username"].nunique()
# Out:
# 20168

# %%
UBS["Username"].nunique()
# Out:
# 26648

# %%
MS["Username"].nunique()
# Out:
# 18817

# %%
GS["Username"].nunique()
# Out:
# 13935

# %% [markdown]
# # Studying the columns needed to build the propensity scoring !!!
# 1. Skill set
# 2. Gender
# 3. Age
# 4. Education

# %% [markdown]
# ## Learning about the skill set column

# %%
LEH["Skillset1"].dtype, UBS["Skillset1"].dtype, DB["Skillset1"].dtype, MS["Skillset1"].dtype, GS["Skillset1"].dtype
# Out:
# (dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'))

# %%
LEH["Skillset1"].unique()
# Out:
# array(['-1', 'Banking and Finance', 'Education',
#        'Accounting and Auditing', 'Real Estate',
#        'IT Management and Support', 'Sales',
#        'Technical Product Management', 'Business Development',
#        'Administration', 'CRM and Sales Management',
#        'Software Engineering', 'Video and Film Production', 'Insurance',
#        'Middle Management', 'Digital Marketing', 'Recruiting',
#        'Operations Management', 'Healthcare', 'Data Analysis',
#        'Social Media and Communications', 'Sales Management',
#        'Visual Design', 'Web Design', 'Web Development',
#        'Human Resources (Junior)', 'Legal', 'Hospitality',
#        'Human Resources (Senior)', 'Military', 'Graphic Design',
#        'Mobile Telecommunications', 'Logistics', 'Musical Production',
#        'Energy, Oil, and Gas', 'Public Policy', 'Construction Management',
#        'Non-Profit and Community', 'Electrical Engineering',
#        'Personal Coaching', 'Retail and Fashion', 'Product Management',
#        'Pharmaceutical', 'Industrial Management'], dtype=object)

# %%
UBS["Skillset1"].unique()
# Out:
# array(['-1', 'Operations Management', 'Banking and Finance',
#        'Technical Product Management', 'Business Development',
#        'IT Management and Support', 'Software Engineering',
#        'Digital Marketing', 'Human Resources (Junior)',
#        'Middle Management', 'Healthcare', 'Accounting and Auditing',
#        'Sales Management', 'Administration', 'CRM and Sales Management',
#        'Human Resources (Senior)', 'Insurance', 'Web Design',
#        'Mobile Telecommunications', 'Sales',
#        'Social Media and Communications', 'Public Policy', 'Legal',
#        'Web Development', 'Recruiting', 'Industrial Management',
#        'Graphic Design', 'Manufacturing and Process Management',
#        'Visual Design', 'Non-Profit and Community', 'Real Estate',
#        'Video and Film Production', 'Product Management', 'Education',
#        'Data Analysis', 'Logistics', 'Electrical Engineering',
#        'Hospitality', 'Military', 'Construction Management',
#        'Energy, Oil, and Gas', 'Personal Coaching', 'Pharmaceutical',
#        'Retail and Fashion', 'Musical Production'], dtype=object)

# %%
DB["Skillset1"].unique()
# Out:
# array(['-1', 'Banking and Finance', 'Operations Management',
#        'Human Resources (Senior)', 'IT Management and Support',
#        'Pharmaceutical', 'Accounting and Auditing',
#        'Software Engineering', 'Business Development',
#        'Industrial Management', 'Recruiting', 'Graphic Design',
#        'Data Analysis', 'Technical Product Management', 'Web Design',
#        'CRM and Sales Management', 'Middle Management',
#        'Sales Management', 'Real Estate', 'Sales', 'Product Management',
#        'Insurance', 'Personal Coaching', 'Legal', 'Administration',
#        'Military', 'Video and Film Production', 'Retail and Fashion',
#        'Social Media and Communications', 'Web Development',
#        'Construction Management', 'Logistics', 'Musical Production',
#        'Human Resources (Junior)', 'Energy, Oil, and Gas',
#        'Public Policy', 'Digital Marketing', 'Education',
#        'Mobile Telecommunications', 'Hospitality',
#        'Non-Profit and Community', 'Healthcare', 'Visual Design',
#        'Electrical Engineering', 'Manufacturing and Process Management'],
#       dtype=object)

# %%
MS["Skillset1"].unique()
# Out:
# array(['-1', 'Software Engineering', 'Banking and Finance',
#        'Middle Management', 'Technical Product Management', 'Recruiting',
#        'Social Media and Communications', 'Insurance', 'Sales Management',
#        'CRM and Sales Management', 'Operations Management',
#        'Business Development', 'Legal', 'Data Analysis',
#        'Construction Management', 'Accounting and Auditing', 'Web Design',
#        'Administration', 'IT Management and Support', 'Web Development',
#        'Real Estate', 'Graphic Design', 'Non-Profit and Community',
#        'Hospitality', 'Energy, Oil, and Gas', 'Product Management',
#        'Sales', 'Video and Film Production', 'Visual Design',
#        'Human Resources (Junior)', 'Manufacturing and Process Management',
#        'Logistics', 'Mobile Telecommunications', 'Education', 'Military',
#        'Digital Marketing', 'Musical Production',
#        'Human Resources (Senior)', 'Industrial Management',
#        'Retail and Fashion', 'Healthcare', 'Personal Coaching',
#        'Public Policy', 'Pharmaceutical'], dtype=object)

# %%
GS["Skillset1"].unique()
# Out:
# array(['-1', 'Banking and Finance', 'Software Engineering',
#        'IT Management and Support', 'Middle Management',
#        'Human Resources (Senior)', 'Insurance', 'Business Development',
#        'Administration', 'Technical Product Management', 'Recruiting',
#        'Healthcare', 'Visual Design', 'Digital Marketing',
#        'Operations Management', 'Mobile Telecommunications',
#        'Accounting and Auditing', 'Real Estate', 'Data Analysis',
#        'Sales Management', 'Human Resources (Junior)',
#        'Construction Management', 'Non-Profit and Community',
#        'Web Development', 'Personal Coaching', 'Military', 'Legal',
#        'Video and Film Production', 'Web Design',
#        'CRM and Sales Management', 'Hospitality',
#        'Social Media and Communications', 'Sales',
#        'Electrical Engineering', 'Energy, Oil, and Gas', 'Logistics',
#        'Education', 'Public Policy', 'Industrial Management',
#        'Graphic Design', 'Retail and Fashion', 'Pharmaceutical',
#        'Product Management', 'Manufacturing and Process Management',
#        'Musical Production'], dtype=object)

# %% [markdown]
# All the skill set1 columns are of string type and NAN value is seemed to be replaced with -1.

# %% [markdown]
# ## Gender

# %%
LEH["Gender"].dtype, UBS["Gender"].dtype, DB["Gender"].dtype, MS["Gender"].dtype, GS["Gender"].dtype
# Out:
# (dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'))

# %%
LEH["Gender"].value_counts()
# Out:
# 2    55743
# 0    24662
# 1    21698
# Name: Gender, dtype: int64

# %%
LEH["Gender"].unique(), UBS["Gender"].unique(), DB["Gender"].unique(), MS["Gender"].unique(), GS["Gender"].unique()
# Out:
# (array([1, 0, 2]),
#  array([2, 1, 0]),
#  array([2, 1, 0]),
#  array([1, 0, 2]),
#  array([2, 0, 1]))

# %% [markdown]
# The data type is numerical(int). 1 corresponds to female, 2 corresponds to male and 0 correspond to unknown. The birth gender can be inferred from the namee of the employee.

# %% [markdown]
# ## Age

# %%
#the missing values are replaced by the None string
LEH["Birth Year"].unique()
# Out:
# array([1983, 1972, 1988, 1966, 1975, 2000, 1965, 1984, 1932, 1980, 1969,
#        1978, 1973, 1985, 1977, 1976, 1979, 1968, 1982, 1974, 1971, 1970,
#        1967, 1959, 1981, 1989, 1960, 1951, 1952, 1987, 1961, 1964, 1957,
#        1986, 1962, 1949, 1948, 1940, 1958, 1954, 1953, 1945, 1942, 1934,
#        1963, 1955, 1956, 1944, 1947, 1923, 1946, 1931, 1941, 1950, 1939,
#        1935, '2000', '1979', '1982', '1974', '1976', '1980', '1960',
#        '1984', '1967', '1989', '1969', '1977', '1985', '1981', '1978',
#        '1983', '1968', '1971', '1973', '1966', '1975', '1965', '1970',
#        '1986', '1972', '1964', '1952', '1955', '1962', '1953', '1963',
#        '1958', '1956', '1988', '1954', '1957', '1961', '1946', '1950',
#        '1987', '1951', '1948', '1926', '1959', '1941', '1931', '1944',
#        '1949', '1945', 'None', '1937', '1929', '1932', '1936', '1938',
#        '1947', '1933', '1940', '1943', '1920', '1939', '1934'],
#       dtype=object)

# %%
LEH[LEH["Birth Year"] == "None"]
# Out:
#                                    Username              Name Birth Year  \
# 45927  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45928  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45929  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45930  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45931  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45932  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45933  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45934  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45935  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45936  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45937  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45938  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45939  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45940  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45941  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45942  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45943  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45944  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45945  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45946  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45947  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45948  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45949  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45950  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45951  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45952  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45953  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45954  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45955  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# 45956  5b7185c9-c602-3ccd-9429-9015e7f7b3e4      Mark Langdon       None
# ...                                     ...               ...        ...
# 70740  23458707-a836-359f-a2be-fdbf8e583d70     Vanda Phillip       None
# 86776  3aa8474d-8d51-3d1e-a7c6-280d42badab2       Eric McCann       None
# 86777  3aa8474d-8d51-3d1e-a7c6-280d42badab2       Eric McCann       None
# 86778  3aa8474d-8d51-3d1e-a7c6-280d42badab2       Eric McCann       None
# 86779  3aa8474d-8d51-3d1e-a7c6-280d42badab2       Eric McCann       None
# 86780  3aa8474d-8d51-3d1e-a7c6-280d42badab2       Eric McCann       None
# 86781  3aa8474d-8d51-3d1e-a7c6-280d42badab2       Eric McCann       None
# 86782  3aa8474d-8d51-3d1e-a7c6-280d42badab2       Eric McCann       None
# 86783  3aa8474d-8d51-3d1e-a7c6-280d42badab2       Eric McCann       None
# 86784  3aa8474d-8d51-3d1e-a7c6-280d42badab2       Eric McCann       None
# 86785  3aa8474d-8d51-3d1e-a7c6-280d42badab2       Eric McCann       None
# 86786  3aa8474d-8d51-3d1e-a7c6-280d42badab2       Eric McCann       None
# 86787  3aa8474d-8d51-3d1e-a7c6-280d42badab2       Eric McCann       None
# 86788  3aa8474d-8d51-3d1e-a7c6-280d42badab2       Eric McCann       None
# 86789  3aa8474d-8d51-3d1e-a7c6-280d42badab2       Eric McCann       None
# 86790  3aa8474d-8d51-3d1e-a7c6-280d42badab2       Eric McCann       None
# 86791  3aa8474d-8d51-3d1e-a7c6-280d42badab2       Eric McCann       None
# 86792  3aa8474d-8d51-3d1e-a7c6-280d42badab2       Eric McCann       None
# 86793  3aa8474d-8d51-3d1e-a7c6-280d42badab2       Eric McCann       None
# 86794  3aa8474d-8d51-3d1e-a7c6-280d42badab2       Eric McCann       None
# 86795  3aa8474d-8d51-3d1e-a7c6-280d42badab2       Eric McCann       None
# 98005  c187c388-66fc-3810-94aa-b0323d272b33  M PETER tsigakos       None
# 98006  c187c388-66fc-3810-94aa-b0323d272b33  M PETER tsigakos       None
# 98007  c187c388-66fc-3810-94aa-b0323d272b33  M PETER tsigakos       None
# 98008  c187c388-66fc-3810-94aa-b0323d272b33  M PETER tsigakos       None
# 98009  c187c388-66fc-3810-94aa-b0323d272b33  M PETER tsigakos       None
# 98010  c187c388-66fc-3810-94aa-b0323d272b33  M PETER tsigakos       None
# 98011  c187c388-66fc-3810-94aa-b0323d272b33  M PETER tsigakos       None
# 98012  c187c388-66fc-3810-94aa-b0323d272b33  M PETER tsigakos       None
# 98013  c187c388-66fc-3810-94aa-b0323d272b33  M PETER tsigakos       None
#
#        Gender Skillset1  Skillset1 Weight Skillset2  Skillset2 Weight  \
# 45927       2        -1               0.0        -1               0.0
# 45928       2        -1               0.0        -1               0.0
# 45929       2        -1               0.0        -1               0.0
# 45930       2        -1               0.0        -1               0.0
# 45931       2        -1               0.0        -1               0.0
# 45932       2        -1               0.0        -1               0.0
# 45933       2        -1               0.0        -1               0.0
# 45934       2        -1               0.0        -1               0.0
# 45935       2        -1               0.0        -1               0.0
# 45936       2        -1               0.0        -1               0.0
# 45937       2        -1               0.0        -1               0.0
# 45938       2        -1               0.0        -1               0.0
# 45939       2        -1               0.0        -1               0.0
# 45940       2        -1               0.0        -1               0.0
# 45941       2        -1               0.0        -1               0.0
# 45942       2        -1               0.0        -1               0.0
# 45943       2        -1               0.0        -1               0.0
# 45944       2        -1               0.0        -1               0.0
# 45945       2        -1               0.0        -1               0.0
# 45946       2        -1               0.0        -1               0.0
# 45947       2        -1               0.0        -1               0.0
# 45948       2        -1               0.0        -1               0.0
# 45949       2        -1               0.0        -1               0.0
# 45950       2        -1               0.0        -1               0.0
# 45951       2        -1               0.0        -1               0.0
# 45952       2        -1               0.0        -1               0.0
# 45953       2        -1               0.0        -1               0.0
# 45954       2        -1               0.0        -1               0.0
# 45955       2        -1               0.0        -1               0.0
# 45956       2        -1               0.0        -1               0.0
# ...       ...       ...               ...       ...               ...
# 70740       1        -1               0.0        -1               0.0
# 86776       2        -1               0.0        -1               0.0
# 86777       2        -1               0.0        -1               0.0
# 86778       2        -1               0.0        -1               0.0
# 86779       2        -1               0.0        -1               0.0
# 86780       2        -1               0.0        -1               0.0
# 86781       2        -1               0.0        -1               0.0
# 86782       2        -1               0.0        -1               0.0
# 86783       2        -1               0.0        -1               0.0
# 86784       2        -1               0.0        -1               0.0
# 86785       2        -1               0.0        -1               0.0
# 86786       2        -1               0.0        -1               0.0
# 86787       2        -1               0.0        -1               0.0
# 86788       2        -1               0.0        -1               0.0
# 86789       2        -1               0.0        -1               0.0
# 86790       2        -1               0.0        -1               0.0
# 86791       2        -1               0.0        -1               0.0
# 86792       2        -1               0.0        -1               0.0
# 86793       2        -1               0.0        -1               0.0
# 86794       2        -1               0.0        -1               0.0
# 86795       2        -1               0.0        -1               0.0
# 98005       0        -1               0.0        -1               0.0
# 98006       0        -1               0.0        -1               0.0
# 98007       0        -1               0.0        -1               0.0
# 98008       0        -1               0.0        -1               0.0
# 98009       0        -1               0.0        -1               0.0
# 98010       0        -1               0.0        -1               0.0
# 98011       0        -1               0.0        -1               0.0
# 98012       0        -1               0.0        -1               0.0
# 98013       0        -1               0.0        -1               0.0
#
#                 City         Country       ...          Flag  \
# 45927  New York City   United States       ...         False
# 45928  New York City   United States       ...         False
# 45929  New York City   United States       ...         False
# 45930  New York City   United States       ...          True
# 45931  New York City   United States       ...         False
# 45932  New York City   United States       ...          True
# 45933  New York City   United States       ...         False
# 45934  New York City   United States       ...          True
# 45935  New York City   United States       ...         False
# 45936  New York City   United States       ...          True
# 45937  New York City   United States       ...          True
# 45938  New York City   United States       ...          True
# 45939  New York City   United States       ...         False
# 45940  New York City   United States       ...          True
# 45941  New York City   United States       ...         False
# 45942  New York City   United States       ...          True
# 45943  New York City   United States       ...          True
# 45944  New York City   United States       ...          True
# 45945  New York City   United States       ...          True
# 45946  New York City   United States       ...         False
# 45947  New York City   United States       ...         False
# 45948  New York City   United States       ...          True
# 45949  New York City   United States       ...          True
# 45950  New York City   United States       ...         False
# 45951  New York City   United States       ...         False
# 45952  New York City   United States       ...          True
# 45953  New York City   United States       ...          True
# 45954  New York City   United States       ...          True
# 45955  New York City   United States       ...          True
# 45956  New York City   United States       ...          True
# ...              ...             ...       ...           ...
# 70740  New York City   United States       ...         False
# 86776      Rochester  United Kingdom       ...         False
# 86777      Rochester  United Kingdom       ...         False
# 86778      Rochester  United Kingdom       ...         False
# 86779      Rochester  United Kingdom       ...         False
# 86780      Rochester  United Kingdom       ...         False
# 86781      Rochester  United Kingdom       ...         False
# 86782      Rochester  United Kingdom       ...         False
# 86783      Rochester  United Kingdom       ...         False
# 86784      Rochester  United Kingdom       ...         False
# 86785      Rochester  United Kingdom       ...         False
# 86786      Rochester  United Kingdom       ...         False
# 86787      Rochester  United Kingdom       ...         False
# 86788      Rochester  United Kingdom       ...         False
# 86789      Rochester  United Kingdom       ...         False
# 86790      Rochester  United Kingdom       ...          True
# 86791      Rochester  United Kingdom       ...         False
# 86792      Rochester  United Kingdom       ...         False
# 86793      Rochester  United Kingdom       ...         False
# 86794      Rochester  United Kingdom       ...         False
# 86795      Rochester  United Kingdom       ...         False
# 98005  New York City   United States       ...         False
# 98006  New York City   United States       ...         False
# 98007  New York City   United States       ...         False
# 98008  New York City   United States       ...         False
# 98009  New York City   United States       ...          True
# 98010  New York City   United States       ...          True
# 98011  New York City   United States       ...          True
# 98012  New York City   United States       ...          True
# 98013  New York City   United States       ...         False
#
#                                      Location  Industry Education Flag  \
# 45927                                     NaN       NaN           True
# 45928                                     NaN       NaN           True
# 45929                           United States  TIME_OFF          False
# 45930                                     NaN    325412          False
# 45931              greater new york city area        51          False
# 45932                                     NaN        54          False
# 45933                                     NaN       NaN          False
# 45934                                     NaN    522110          False
# 45935                                     NaN       NaN          False
# 45936                                     NaN    522110          False
# 45937                       search consultant    523920          False
# 45938                                     NaN    523110          False
# 45939                                     NaN       NaN          False
# 45940                                     NaN        54          False
# 45941                                     NaN       NaN          False
# 45942                                     NaN    522110          False
# 45943                                     NaN    522110          False
# 45944                                     NaN    523110          False
# 45945                                     NaN    519130          False
# 45946                                     NaN       621          False
# 45947                                     NaN       NaN          False
# 45948                                     NaN    561450          False
# 45949                                     NaN    523930          False
# 45950                                     NaN        52          False
# 45951                                     NaN       NaN          False
# 45952                                     NaN        11          False
# 45953                                     NaN    423690          False
# 45954                                     NaN    515210          False
# 45955                                     NaN    511210          False
# 45956                                     NaN    522110          False
# ...                                       ...       ...            ...
# 70740                            new york, ny        62          False
# 86776                                     NaN       NaN           True
# 86777                          United Kingdom  TIME_OFF          False
# 86778                                     NaN    928110          False
# 86779                              world wide    928110          False
# 86780                                     NaN       NaN          False
# 86781                                     NaN       NaN          False
# 86782                                     NaN        23          False
# 86783                                     NaN       NaN          False
# 86784                                     NaN       NaN          False
# 86785                                     NaN        54          False
# 86786                                     NaN       NaN          False
# 86787                                     NaN        54          False
# 86788                                     NaN       NaN          False
# 86789                                     NaN        52          False
# 86790                                     NaN    522110          False
# 86791                                     NaN       NaN           True
# 86792                                     NaN       NaN           True
# 86793                                     NaN       NaN          False
# 86794  london, south east and tunbridge wells       NaN          False
# 86795                        london, national       NaN          False
# 98005                                     NaN       NaN           True
# 98006                           United States  TIME_OFF          False
# 98007                                     NaN       NaN           True
# 98008                           United States  TIME_OFF          False
# 98009                                     NaN    522110          False
# 98010                                     NaN    522110          False
# 98011                                     NaN    522110          False
# 98012                                     NaN    522110          False
# 98013                                     NaN       NaN           True
#
#       Degree Type  Elite Flag             Major  Department(major category)  \
# 45927         4.0       False               NaN                         NaN
# 45928         4.0       False  computer science                 Engineering
# 45929         NaN       False               NaN                         NaN
# 45930         NaN       False               NaN                         NaN
# 45931         NaN       False               NaN                         NaN
# 45932         NaN       False               NaN                         NaN
# 45933         NaN       False               NaN                         NaN
# 45934         NaN       False               NaN                         NaN
# 45935         NaN       False               NaN                         NaN
# 45936         NaN       False               NaN                         NaN
# 45937         NaN       False               NaN                         NaN
# 45938         NaN       False               NaN                         NaN
# 45939         NaN       False               NaN                         NaN
# 45940         NaN       False               NaN                         NaN
# 45941         NaN       False               NaN                         NaN
# 45942         NaN       False               NaN                         NaN
# 45943         NaN       False               NaN                         NaN
# 45944         NaN       False               NaN                         NaN
# 45945         NaN       False               NaN                         NaN
# 45946         NaN       False               NaN                         NaN
# 45947         NaN       False               NaN                         NaN
# 45948         NaN       False               NaN                         NaN
# 45949         NaN       False               NaN                         NaN
# 45950         NaN       False               NaN                         NaN
# 45951         NaN       False               NaN                         NaN
# 45952         NaN       False               NaN                         NaN
# 45953         NaN       False               NaN                         NaN
# 45954         NaN       False               NaN                         NaN
# 45955         NaN       False               NaN                         NaN
# 45956         NaN       False               NaN                         NaN
# ...           ...         ...               ...                         ...
# 70740         NaN       False               NaN                         NaN
# 86776         1.0       False               NaN                         NaN
# 86777         NaN       False               NaN                         NaN
# 86778         NaN       False               NaN                         NaN
# 86779         NaN       False               NaN                         NaN
# 86780         NaN       False               NaN                         NaN
# 86781         NaN       False               NaN                         NaN
# 86782         NaN       False               NaN                         NaN
# 86783         NaN       False               NaN                         NaN
# 86784         NaN       False               NaN                         NaN
# 86785         NaN       False               NaN                         NaN
# 86786         NaN       False               NaN                         NaN
# 86787         NaN       False               NaN                         NaN
# 86788         NaN       False               NaN                         NaN
# 86789         NaN       False               NaN                         NaN
# 86790         NaN       False               NaN                         NaN
# 86791         NaN       False               law             Social Sciences
# 86792         4.0       False    management,law             Social Sciences
# 86793         NaN       False               NaN                         NaN
# 86794         NaN       False               NaN                         NaN
# 86795         NaN       False               NaN                         NaN
# 98005         4.0       False        management             Social Sciences
# 98006         NaN       False               NaN                         NaN
# 98007         6.0       False        management             Social Sciences
# 98008         NaN       False               NaN                         NaN
# 98009         NaN       False               NaN                         NaN
# 98010         NaN       False               NaN                         NaN
# 98011         NaN       False               NaN                         NaN
# 98012         NaN       False               NaN                         NaN
# 98013         5.0       False        management             Social Sciences
#
#                FIGI       Time Stamp
# 45927           NaN    1538814482000
# 45928           NaN    1538814482000
# 45929           NaN    1538814482000
# 45930  BBG000BR2B91    1538814482000
# 45931           NaN    1538814482000
# 45932  BBG000C1K7N0    1538814482000
# 45933           NaN    1538814482000
# 45934  BBG000BBZTH2    1538814482000
# 45935           NaN    1538814482000
# 45936  BBG000DMBXR2    1538814482000
# 45937  BBG007DJM539    1538814482000
# 45938  BBG000BS1R22    1538814482000
# 45939           NaN    1538814482000
# 45940  BBG000BRVF72    1538814482000
# 45941           NaN    1538814482000
# 45942           NaN    1538814482000
# 45943           NaN    1538814482000
# 45944  BBG000BLZRJ2    1538814482000
# 45945  BBG000BFK1R9    1538814482000
# 45946           NaN    1538814482000
# 45947           NaN    1538814482000
# 45948  BBG000BP1Q11    1538814482000
# 45949  BBG001LRKS55    1538814482000
# 45950           NaN    1538814482000
# 45951           NaN    1538814482000
# 45952  BBG000BLNNH6    1538814482000
# 45953  BBG000BCD3D5    1538814482000
# 45954  BBG000BWQFY7    1538814482000
# 45955  BBG000BQLTW7    1538814482000
# 45956  BBG000BD8PN9    1538814482000
# ...             ...              ...
# 70740           NaN    1538851691000
# 86776           NaN    1540925520000
# 86777           NaN    1540925520000
# 86778           NaN    1540925520000
# 86779           NaN    1540925520000
# 86780           NaN    1540925520000
# 86781           NaN    1540925520000
# 86782           NaN    1540925520000
# 86783           NaN    1540925520000
# 86784           NaN    1540925520000
# 86785           NaN    1540925520000
# 86786           NaN    1540925520000
# 86787           NaN    1540925520000
# 86788           NaN    1540925520000
# 86789           NaN    1540925520000
# 86790           NaN    1540925520000
# 86791           NaN    1540925520000
# 86792           NaN    1540925520000
# 86793           NaN    1540925520000
# 86794           NaN    1540925520000
# 86795           NaN    1540925520000
# 98005           NaN  -61759706021000
# 98006           NaN  -61759706021000
# 98007           NaN  -61759706021000
# 98008           NaN  -61759706021000
# 98009           NaN  -61759706021000
# 98010           NaN  -61759706021000
# 98011           NaN  -61759706021000
# 98012           NaN  -61759706021000
# 98013           NaN  -61759706021000
#
# [114 rows x 34 columns]

# %%
"None" in DB["Birth Year"].unique()
# Out:
# True

# %%
DB[DB["Birth Year"] == "None"]["Birth Year"].value_counts()
# Out:
# None    219
# Name: Birth Year, dtype: int64

# %%
"None" in MS["Birth Year"].unique()
# Out:
# True

# %%
"None" in UBS["Birth Year"].unique()
# Out:
# True

# %%
"None" in GS["Birth Year"].unique()
# Out:
# True

# %% [markdown]
# Based on my observation, the age for each employee as 2008 can be calculated by subtracting the birth year from 2008. The none rows are ignored.

# %% [markdown]
# ## Education
# The educational level of an employee is studied through two aspects.
# 1. highest education -- highest degree attained
# 2. elite instituition

# %%
LEH["Education(highest degree attained)"].unique(), LEH["Education(highest degree attained)"].dtype
# Out:
# (array([4, 6, 0, 3, 5, 7, 1, 2]), dtype('int64'))

# %%
DB["Education(highest degree attained)"].unique(), DB["Education(highest degree attained)"].dtype
# Out:
# (array([4, 2, 0, 6, 5, 1, 7, 3]), dtype('int64'))

# %%
UBS["Education(highest degree attained)"].unique(), UBS["Education(highest degree attained)"].dtype
# Out:
# (array([5, 0, 4, 1, 7, 6, 3, 2]), dtype('int64'))

# %%
MS["Education(highest degree attained)"].unique(), MS["Education(highest degree attained)"].dtype
# Out:
# (array([4, 5, 0, 6, 1, 7, 2, 3]), dtype('int64'))

# %%
GS["Education(highest degree attained)"].unique(), GS["Education(highest degree attained)"].dtype
# Out:
# (array([7, 0, 4, 5, 6, 1, 2, 3]), dtype('int64'))

# %% [markdown]
# The Degree column is consistent witd description given and they are of int values.

# %% [markdown]
# # Analysing LEHMAN employees

# %%
#obtained the important columns from lehman table
LT = LEH[["Username", "Name", "Start Date", "End Date", "Company Name", "Industry"]]

# %%
#Set the end date column to datetime object
#converted the company name to lowercase
LT.loc[:,"End Date"] = pd.to_datetime(LEH["End Date"], format = '%Y-%m-%d', errors = 'coerce')
LT.loc[:,"Start Date"] = pd.to_datetime(LEH["Start Date"], format = '%Y-%m-%d', errors = 'coerce')
LT.loc[:,"Company Name"] = LT["Company Name"].str.lower()

# %%
#Filtered the lehman table to obtain the end date as of 2008/01/01 and company name is set to be lehman and obtained the list
#of id's of the employees.
#utiized the fill na method to fill the nan values with no company reported

Lehman_employees = LT[LT["Company Name"].fillna("No company reported").str.contains("lehman")].copy()
Lehman_employees.sort_values("End Date", ascending = True, inplace = True)
date_2008 = pd.Timestamp(2008, 1,1).date()

Lehman_time2 =  (Lehman_employees["End Date"].dt.date >= date_2008)
LH_2008 = Lehman_employees[Lehman_time2]
Lst_of_ID = list(LH_2008[~LH_2008["Username"].duplicated()]["Username"])

# %%
# considered where the end date is greater than or equal to 2016-01-01
#only took the first row for each employee to note their industry as of 2016-01-01
m = pd.Timestamp(2016, 1, 1).date()
Filtered_based_on_datesLH = LT[ LT["End Date"].dt.date >= m]
Employees_consideredLH = Filtered_based_on_datesLH[Filtered_based_on_datesLH["Username"].isin(Lst_of_ID)]
Employeed_consideredLH = Employees_consideredLH[~Employees_consideredLH["Username"].duplicated()]

# %%
# function to apply to find out the other the industry
def industry(m):
    if m == "nan" or m == "missing" or m == "time_off":
        return 3
    elif "52" in m:
        return 1
    
    else:
        return 2

# %%
Employees_consideredLH.loc[:, "Industry"] = Employees_consideredLH["Industry"].astype(str).str.lower()
Employees_consideredLH.loc[:, "Finance"] = Employees_consideredLH["Industry"].apply(industry)

# %%
FinanceLH = Employees_consideredLH.groupby("Finance").size()
FinanceLH
# Out:
# Finance
# 1    2417
# 2    1945
# 3    2351
# dtype: int64

# %% [markdown]
# # Analysis on DB Bank

# %%
# Collecting the needed columns
# converting the datetime strings to datetime object
#converting all the company name to lower case
DB_Bank = DB[["Username", "Name", "Start Date", "End Date", "Company Name", "Industry"]].copy()
DB_Bank.loc[:,"End Date"] = pd.to_datetime(DB_Bank["End Date"], format = '%Y-%m-%d', errors = 'coerce')
DB_Bank.loc[:,"Start Date"] = pd.to_datetime(DB_Bank["Start Date"], format = '%Y-%m-%d', errors = 'coerce')
DB_Bank.loc[:,"Company Name"] = DB_Bank["Company Name"].str.lower()
DB_Bank.sort_values("End Date", ascending = True, inplace = True)
DB_Bank.head()
# Out:
#                                     Username            Name Start Date  \
# 50564   03de0d25-7d61-305e-9a8e-3ac1b5b622b5     Doug McCrea 1902-01-01
# 50565   03de0d25-7d61-305e-9a8e-3ac1b5b622b5     Doug McCrea 1918-01-01
# 145078  a39903fd-8eee-3303-ad29-904f1da1eb28    SYLVAN MASON 1953-01-01
# 145079  a39903fd-8eee-3303-ad29-904f1da1eb28    SYLVAN MASON 1956-01-01
# 160734  c54740a1-cbeb-3f05-8ca5-761baa73402e  Maryann Hercek 1956-01-01
#
#          End Date                                      Company Name  Industry
# 50564  1905-01-01  university of west florida - college of business       NaN
# 50565  1922-01-01                          florida state university       NaN
# 145078 1956-01-01                     rowan hill preparatory school       NaN
# 145079 1957-12-01                                          time_off  TIME_OFF
# 160734 1960-01-01                              garfield high school       NaN

# %%
#Filtered the DB table to obtain the end date as of 2008/01/01 and company name is set to be deutshe bank and obtained the list
#of id's of the employees.
#utiized the fill na method to fill the nan values with no company reported

DB_employees = DB_Bank[DB_Bank["Company Name"].fillna("No company reported").str.contains("deutsche bank")].copy()
date_2008 = pd.Timestamp(2008, 1,1).date()
DB_time2 =  (DB_employees["End Date"].dt.date >= date_2008)
DB_2008 = DB_employees[DB_time2]
Lst_of_IDDB = list(DB_2008[~DB_2008["Username"].duplicated()]["Username"])

# %%
# considered where the end date is greater than or equal to 2016-01-01
#only took the first row for each employee to note their industry as of 2016-01-01
m = pd.Timestamp(2016, 1, 1).date()
Filtered_based_on_datesDB = DB_Bank[DB_Bank["End Date"].dt.date >= m]
Employees_consideredDB = Filtered_based_on_datesDB[Filtered_based_on_datesDB["Username"].isin(Lst_of_IDDB)]
Employeed_consideredDB = Employees_consideredDB[~Employees_consideredDB["Username"].duplicated()]
Employees_consideredDB.loc[:, "Industry"] = Employees_consideredDB["Industry"].astype(str).str.lower()
Employees_consideredDB.loc[:, "Finance"] = Employees_consideredDB["Industry"].apply(industry)

# %%
FinanceDB = Employees_consideredDB.groupby("Finance").size()

# %% [markdown]
# # Analysis of GS bank

# %%
# Collecting the needed columns
# converting the datetime strings to datetime object
#converting all the company name to lower case
GS_Bank = GS[["Username", "Name", "Start Date", "End Date", "Company Name", "Industry"]].copy()
GS_Bank.loc[:,"End Date"] = pd.to_datetime(GS_Bank["End Date"], format = '%Y-%m-%d', errors = 'coerce')
GS_Bank.loc[:,"Start Date"] = pd.to_datetime(GS_Bank["Start Date"], format = '%Y-%m-%d', errors = 'coerce')
GS_Bank.loc[:,"Company Name"] = GS_Bank["Company Name"].str.lower()
GS_Bank.sort_values("End Date", ascending = True, inplace = True)
GS_Bank.head()
# Out:
#                                    Username                       Name  \
# 93882  df338036-42ee-392c-aa14-94239b3e5f77           Mitchell Budwick
# 61978  9a9b421f-1bb3-300a-bc68-2f8546033656  Dr Stephen Crawford (PhD)
# 83064  b27e606f-963f-3e53-9c33-83de9b973a6d               Ken Newcombe
# 21557  758e1b99-b185-35c4-8086-8bc547a48182             Robert Hormats
# 26262  524a2d8b-5a18-357f-9e9a-a8be679ea3b3         Kathleen O'Donnell
#
#       Start Date   End Date                   Company Name Industry
# 93882 1901-01-01 1901-01-01                       pershing      NaN
# 61978 1956-01-01 1963-01-01  mill hill comprehensive local      NaN
# 83064 1960-01-01 1965-01-01            geelong high school      NaN
# 21557 1961-01-01 1965-01-01               tufts university      NaN
# 26262 1961-01-01 1965-01-01      st . michaels high school      NaN

# %%
# the GS table to obtain the end date as of 2008/01/01 and company name is set to be goldman sachs and obtained the list
#of id's of the employees.
#utiized the fill na method to fill the nan values with no company reported

GS_employees = GS_Bank[GS_Bank["Company Name"].fillna("No company reported").str.contains("goldman sachs")].copy()
date_2008 = pd.Timestamp(2008, 1,1).date()
GS_time2 =  (GS_employees["End Date"].dt.date >= date_2008)
GS_2008 = GS_employees[GS_time2]
Lst_of_IDGS = list(GS_2008[~GS_2008["Username"].duplicated()]["Username"])

# %%
# considered where the end date is greater than or equal to 2016-01-01
#only took the first row for each employee to note their industry as of 2016-01-01
m = pd.Timestamp(2016, 1, 1).date()
Filtered_based_on_datesGS = GS_Bank[GS_Bank["End Date"].dt.date >= m]
Employees_consideredGS = Filtered_based_on_datesGS[Filtered_based_on_datesGS["Username"].isin(Lst_of_IDGS)]
Employeed_consideredGS = Employees_consideredGS[~Employees_consideredGS["Username"].duplicated()]
Employees_consideredGS.loc[:, "Industry"] = Employees_consideredGS["Industry"].astype(str).str.lower()
Employees_consideredGS.loc[:, "Finance"] = Employees_consideredGS["Industry"].apply(industry)

# %%
FinanceGS = Employees_consideredGS.groupby("Finance").size()

# %% [markdown]
# # Analysis of MS Bank

# %%
# Collecting the needed columns
# converting the datetime strings to datetime object
#converting all the company name to lower case
MS_Bank = MS[["Username", "Name", "Start Date", "End Date", "Company Name", "Industry"]].copy()
MS_Bank.loc[:,"End Date"] = pd.to_datetime(MS_Bank["End Date"], format = '%Y-%m-%d', errors = 'coerce')
MS_Bank.loc[:,"Start Date"] = pd.to_datetime(MS_Bank["Start Date"], format = '%Y-%m-%d', errors = 'coerce')
MS_Bank.loc[:,"Company Name"] = MS_Bank["Company Name"].str.lower()
MS_Bank.sort_values("End Date", ascending = True, inplace = True)
MS_Bank.head()
# Out:
#                                     Username           Name Start Date  \
# 139557  d140f727-5fe1-3070-afdf-09ba4b2b9cb7     John Smith        NaT
# 64237   537ad3dd-06ec-3a6e-9243-e8a25348df96  Duncan Parker        NaT
# 86675   610d87cc-9409-3d69-96f1-188a1f3ce52e   Justin Yeung        NaT
# 86676   610d87cc-9409-3d69-96f1-188a1f3ce52e   Justin Yeung 1902-01-01
# 64238   537ad3dd-06ec-3a6e-9243-e8a25348df96  Duncan Parker 1902-01-01
#
#          End Date             Company Name Industry
# 139557 1901-01-01        bond technologies       51
# 64237  1902-01-01          technical times      NaN
# 86675  1902-01-01                      ibm       11
# 86676  1902-01-01             irving trust      NaN
# 64238  1902-01-01  minyanville media, inc.   519130

# %%
# the MS table to obtain the end date as of 2008/01/01 and company name is set to be morgan stanley and obtained the list
#of id's of the employees.
#utiized the fill na method to fill the nan values with no company reported

MS_employees =  MS_Bank[MS_Bank["Company Name"].fillna("No company reported").str.contains("morgan stanley")].copy()
date_2008 = pd.Timestamp(2008, 1,1).date()
MS_time2 =  (MS_employees["End Date"].dt.date >= date_2008)
MS_2008 = MS_employees[MS_time2]
Lst_of_IDMS = list(MS_2008[~MS_2008["Username"].duplicated()]["Username"])

# %%
# considered where the end date is greater than or equal to 2016-01-01
#only took the first row for each employee to note their industry as of 2016-01-01
m = pd.Timestamp(2016, 1, 1).date()
Filtered_based_on_datesMS = MS_Bank[MS_Bank["End Date"].dt.date >= m]
Employees_consideredMS = Filtered_based_on_datesMS[Filtered_based_on_datesMS["Username"].isin(Lst_of_IDMS)]
Employeed_consideredMS = Employees_consideredMS[~Employees_consideredMS["Username"].duplicated()]
Employees_consideredMS.loc[:, "Industry"] = Employees_consideredMS["Industry"].astype(str).str.lower()
Employees_consideredMS.loc[:, "Finance"] = Employees_consideredMS["Industry"].apply(industry)

# %%
FinanceMS = Employees_consideredMS.groupby("Finance").size()

# %% [markdown]
# # Analysis of UBS Bank

# %%
# Collecting the needed columns
# converting the datetime strings to datetime object
#converting all the company name to lower case
UBS_Bank = UBS[["Username", "Name", "Start Date", "End Date", "Company Name", "Industry"]].copy()
UBS_Bank.loc[:,"End Date"] = pd.to_datetime(UBS_Bank["End Date"], format = '%Y-%m-%d', errors = 'coerce')
UBS_Bank.loc[:,"Start Date"] = pd.to_datetime(UBS_Bank["Start Date"], format = '%Y-%m-%d', errors = 'coerce')
UBS_Bank.loc[:,"Company Name"] = UBS_Bank["Company Name"].str.lower()
#UBS_Bank.sort_values("End Date", ascending = True, inplace = True)
UBS_Bank.head()
# Out:
#                                Username              Name Start Date  \
# 0  b2f27b89-832f-3b03-aaf2-87d6e2ac714f  Lorenz Pfisterer 2003-01-01
# 1  b2f27b89-832f-3b03-aaf2-87d6e2ac714f  Lorenz Pfisterer 2006-08-01
# 2  b2f27b89-832f-3b03-aaf2-87d6e2ac714f  Lorenz Pfisterer 2006-11-01
# 3  b2f27b89-832f-3b03-aaf2-87d6e2ac714f  Lorenz Pfisterer 2007-11-01
# 4  b2f27b89-832f-3b03-aaf2-87d6e2ac714f  Lorenz Pfisterer 2008-08-01
#
#     End Date           Company Name Industry
# 0 2008-01-01     universität zürich      NaN
# 1 2006-10-01  ubs wealth management   523920
# 2 2007-09-01        aebi rc progres      NaN
# 3 2008-04-01  ubs wealth management   523920
# 4 2008-11-01        aebi rc progres      NaN

# %%
# the UBS table to obtain the end date as of 2008/01/01 and company name is set to be ubs and obtained the list
#of id's of the employees.
#utiized the fill na method to fill the nan values with no company reported

UBS_employees =  UBS_Bank[UBS_Bank["Company Name"].fillna("No company reported").str.contains("ubs")].copy()
date_2008 = pd.Timestamp(2008, 1,1).date()
UBS_time2 =  (UBS_employees["End Date"].dt.date >= date_2008)
UBS_2008 = UBS_employees[UBS_time2]
Lst_of_IDUBS = list(UBS_2008[~UBS_2008["Username"].duplicated()]["Username"])

# %%
# considered where the end date is greater than or equal to 2016-01-01
#only took the first row for each employee to note their industry as of 2016-01-01
m = pd.Timestamp(2016, 1, 1).date()
Filtered_based_on_datesUBS = UBS_Bank[UBS_Bank["End Date"].dt.date >= m]
Employees_consideredUBS = Filtered_based_on_datesUBS[Filtered_based_on_datesUBS["Username"].isin(Lst_of_IDUBS)]
Employeed_consideredUBS = Employees_consideredUBS[~Employees_consideredUBS["Username"].duplicated()]
Employees_consideredUBS.loc[:, "Industry"] = Employees_consideredUBS["Industry"].astype(str).str.lower()
Employees_consideredUBS.loc[:, "Finance"] = Employees_consideredUBS["Industry"].apply(industry)

# %%
FinanceUBS = Employees_consideredUBS.groupby("Finance").size()

# %% [markdown]
# # Percentage of Employees in Finance

# %%
Lehman_Percentage = FinanceLH[1]/ FinanceLH.sum()
MS_Percentage = FinanceMS[1]/ FinanceMS.sum()
DB_Percentage = FinanceDB[1]/ FinanceDB.sum()
GS_Percentage = FinanceGS[1]/ FinanceGS.sum()
UBS_Percentage = FinanceUBS[1]/ FinanceUBS.sum()
Lehman_Percentage, MS_Percentage, DB_Percentage, GS_Percentage, UBS_Percentage
# Out:
# (0.3600476687025175,
#  0.4158825081347287,
#  0.4273124124866156,
#  0.41071625041258664,
#  0.37691582174015564)

# %%
x =np.array(["LEH", "MS", "DB", "GS", "UBS"])
y = np.array([0.3600476687025175,0.4158825081347287,0.4273124124866156,0.41071625041258664,0.37691582174015564])*100
sns.set()
sns.barplot(x,y)
plt.xlabel("Type of Banks")
plt.ylabel("Percentage of Employees in Finance %")
plt.title("Percentage of Employees of the firms from 2008 who are working in finance in 2016");
plt.show()
